# %%
import pandas as pd
import numpy as np

df = pd.read_excel("C:/Users/10/Desktop/qsar data (1).xlsx")
df.columns
# Out:
# Index(['mol', 'eC50', 'EC50', 'Log EC50', 'sqrt {EC50}', '1/ {Log EC50}',
#        'log EC50 sqrt', 'density', 'KierFlex', 'Weight',
#        ...
#        'GCUT_SMR_2', 'GCUT_SMR_3', 'vsurf_DD12', 'vsurf_DD13', 'vsurf_DD23',
#        'vsurf_DW12', 'vsurf_DW13', 'vsurf_DW23', 'logP(o/w)', 'logS'],
#       dtype='object', length=255)

# %%
dff = pd.read_excel("C:/Users/10/Desktop/Feature selection results.xlsx")
dff
# Out:
#          Feature
# 0        h_pavgQ
# 1     SlogP_VSA8
# 2     PEOE_VSA-6
# 3      h_pstates
# 4      mutagenic
# 5         MNDO_E
# 6          FASA+
# 7          FASA-
# 8       reactive
# 9          PM3_E
# 10   GCUT_PEOE_0
# 11      AM1_Eele
# 12      vsurf_CP
# 13    SlogP_VSA4
# 14     vsurf_CW2
# 15           ASA
# 16          apol
# 17  GCUT_SLOGP_2
# 18     vsurf_Wp1
# 19       density
# 20    PM3_dipole
# 21      diameter
# 22     logP(o/w)
# 23         ASA_P
# 24        FASA_H
# 25         h_emd
# 26   MNDO_dipole
# 27       dipoleX
# 28    PEOE_VSA-1
# 29    PEOE_VSA+5
# 30    BCUT_SMR_3
# 31      vsurf_W6
# 32       vsurf_A
# 33          npr2
# 34     vsurf_Wp4
# 35    SlogP_VSA6
# 36      vdw_area
# 37          pmiX
# 38         Kier2
# 39  GCUT_SLOGP_0
# 40    Q_VSA_FPOL
# 41  vsurf_EDmin3
# 42      SMR_VSA1
# 43  vsurf_EDmin1
# 44     MNDO_Eele

# %%
features = dff.to_numpy()
features
# Out:
# array([['h_pavgQ'],
#        ['SlogP_VSA8'],
#        ['PEOE_VSA-6'],
#        ['h_pstates'],
#        ['mutagenic'],
#        ['MNDO_E'],
#        ['FASA+'],
#        ['FASA-'],
#        ['reactive'],
#        ['PM3_E'],
#        ['GCUT_PEOE_0'],
#        ['AM1_Eele'],
#        ['vsurf_CP'],
#        ['SlogP_VSA4'],
#        ['vsurf_CW2'],
#        ['ASA'],
#        ['apol'],
#        ['GCUT_SLOGP_2'],
#        ['vsurf_Wp1'],
#        ['density'],
#        ['PM3_dipole'],
#        ['diameter'],
#        ['logP(o/w)'],
#        ['ASA_P'],
#        ['FASA_H'],
#        ['h_emd'],
#        ['MNDO_dipole'],
#        ['dipoleX'],
#        ['PEOE_VSA-1'],
#        ['PEOE_VSA+5'],
#        ['BCUT_SMR_3'],
#        ['vsurf_W6'],
#        ['vsurf_A'],
#        ['npr2'],
#        ['vsurf_Wp4'],
#        ['SlogP_VSA6'],
#        ['vdw_area'],
#        ['pmiX'],
#        ['Kier2'],
#        ['GCUT_SLOGP_0'],
#        ['Q_VSA_FPOL'],
#        ['vsurf_EDmin3'],
#        ['SMR_VSA1'],
# ...

# %%
df
# Out:
#                                                    mol      eC50       EC50  \
# 0      Clc1c(C)cccc1N1CC=2C(=[N+]CCCC)NC(N)=[N+]C=2CC1  0.000001    1000000
# 1     Clc1c(Cl)cccc1N1CC=2C(=[N+]CCCC)NC(N)=[N+]C=2CC1  0.000002    1500000
# 2    Clc1c(N2CC=3C(=[N+]CCCC)NC(N)=[N+]C=3CC2)c(Cl)...  0.000002    2400000
# 3       Clc1c(N2CC=3C(=[N+]CCCC)NC(N)=[N+]C=3CC2)cccc1  0.000002    1500000
# 4                          FC(F)(F)CCCNc1c(OC)cnc(N)n1  0.000006    6500000
# ..                                                 ...       ...        ...
# 251     S(=O)(=O)(C)N1CC=2C(=[N+]CCCC)NC(N)=[N+]C=2CC1  0.000287  287000000
# 252            S(=O)(=O)(C)N1Cc2nc(N)[n+]c(NCCCC)c2CC1  0.000020   20000000
# 253     S(CCCn1c(CCCC)nc2c(N)nc3c(c12)ccc(C(=O)OC)c3)C  0.000004    3840000
# 254      S(CCn1c(CCCC)nc2c(N)nc3c(c12)ccc(C(=O)OC)c3)C  0.000003    2890000
# 255     S(CCn1c(CCCC)nc2c(N)nc3c(c12)ccc(C(=O)OC)c3)CC  0.000007    6670000
#
# ...

# %%
for i in df.columns:
    if i in features:
        None 
    else:
        df = df.drop([i], axis = 1)
df
# Out:
#       density  BCUT_SMR_3  diameter      ASA_P      MNDO_E      PM3_E  \
# 0    0.725057    2.884492        12  153.74876  -93247.344 -84066.328
# 1    0.781410    2.883755        12  164.23853  -97481.859 -87559.273
# 2    0.781410    2.884430        12  154.25450  -97489.281 -87563.750
# 3    0.733150    2.883475        12  150.86629  -89640.000 -80613.883
# 4    0.881346    2.798691         9  228.37170  -90520.133 -81442.797
# ..        ...         ...       ...        ...         ...        ...
# 251  0.788371    2.955930        10  215.28732  -86399.711 -77135.063
# 252  0.788371    2.945006        11  188.07535  -86325.156 -77020.602
# 253  0.739205    2.826133        13  213.73605 -106729.440 -96711.656
# 254  0.747293    2.808823        13  209.29343 -103122.250 -93264.617
# 255  0.739205    2.820164        13  222.38544 -106730.200 -96714.719
#
#       AM1_Eele        ASA   dipoleX        pmiX  ...      Kier2  mutagenic  \
# ...
