# %%
import pandas as pd 
df = pd.read_csv("C:/Users/10/Desktop/QSAR_Clean_Features.csv")
df = df.drop(["Unnamed: 0"], axis=1)
df
# Out:
#                                                    mol  1/ {Log EC50}  \
# 0      Clc1c(C)cccc1N1CC=2C(=[N+]CCCC)NC(N)=[N+]C=2CC1      -0.072382
# 1     Clc1c(Cl)cccc1N1CC=2C(=[N+]CCCC)NC(N)=[N+]C=2CC1      -0.070319
# 2    Clc1c(N2CC=3C(=[N+]CCCC)NC(N)=[N+]C=3CC2)c(Cl)...      -0.068069
# 3       Clc1c(N2CC=3C(=[N+]CCCC)NC(N)=[N+]C=3CC2)cccc1      -0.070319
# 4                          FC(F)(F)CCCNc1c(OC)cnc(N)n1      -0.063746
# ..                                                 ...            ...
# 251     S(=O)(=O)(C)N1CC=2C(=[N+]CCCC)NC(N)=[N+]C=2CC1      -0.051348
# 252            S(=O)(=O)(C)N1Cc2nc(N)[n+]c(NCCCC)c2CC1      -0.059484
# 253     S(CCCn1c(CCCC)nc2c(N)nc3c(c12)ccc(C(=O)OC)c3)C      -0.065959
# 254      S(CCn1c(CCCC)nc2c(N)nc3c(c12)ccc(C(=O)OC)c3)C      -0.067219
# 255     S(CCn1c(CCCC)nc2c(N)nc3c(c12)ccc(C(=O)OC)c3)CC      -0.063641
#
#       density  BCUT_SMR_3  diameter      ASA_P      MNDO_E      PM3_E  \
# 0    0.725057    2.884492        12  153.74876  -93247.344 -84066.328
# 1    0.781410    2.883755        12  164.23853  -97481.859 -87559.273
# 2    0.781410    2.884430        12  154.25450  -97489.281 -87563.750
# 3    0.733150    2.883475        12  150.86629  -89640.000 -80613.883
# 4    0.881346    2.798691         9  228.37170  -90520.133 -81442.797
# ..        ...         ...       ...        ...         ...        ...
# 251  0.788371    2.955930        10  215.28732  -86399.711 -77135.063
# 252  0.788371    2.945006        11  188.07535  -86325.156 -77020.602
# 253  0.739205    2.826133        13  213.73605 -106729.440 -96711.656
# 254  0.747293    2.808823        13  209.29343 -103122.250 -93264.617
# 255  0.739205    2.820164        13  222.38544 -106730.200 -96714.719
#
#       AM1_Eele        ASA  ...      Kier2  mutagenic  PEOE_VSA+5  PEOE_VSA-1  \
# 0   -718895.38  621.95758  ...   8.589506          0   11.190562   81.540749
# 1   -730901.56  616.58264  ...   8.589506          0   11.190562   98.867790
# 2   -735608.56  601.38190  ...   8.589506          0   11.190562   98.867790
# 3   -670500.19  593.35223  ...   8.392734          0   11.190562   81.540749
# 4   -471450.44  450.95105  ...   6.805293          1    0.000000    0.000000
# ..         ...        ...  ...        ...        ...         ...         ...
# 251 -604160.94  540.01416  ...   6.840000          0   11.190562   27.448990
# 252 -595831.38  535.35101  ...   6.840000          1    0.000000   27.448990
# 253 -841633.06  674.72845  ...  10.156250          1   14.708499   27.448990
# 254 -789399.19  652.04883  ...   9.467456          1   14.708499   27.448990
# 255 -846843.81  654.59332  ...  10.156250          1   14.708499   46.196667
#
#      PEOE_VSA-6   vdw_area  GCUT_PEOE_0  GCUT_SLOGP_0  GCUT_SLOGP_2  logP(o/w)
# 0      0.000000  358.46097    -0.823643     -2.204288      0.131865    4.46400
# 1      0.000000  358.81027    -0.823227     -2.204287      0.181145    4.75800
# 2      0.000000  358.81027    -0.820362     -2.204287      0.185399    4.75800
# 3      0.000000  341.22888    -0.823530     -2.204287      0.142239    4.16800
# 4      2.503756  241.60841    -0.808367     -1.335170      0.260200    0.87676
# ..          ...        ...          ...           ...           ...        ...
# 251    0.000000  309.98849    -0.800725     -2.204287      0.054200    0.75500
# 252    0.000000  306.91516    -0.799216     -1.417672      0.094583   -0.08600
# 253    2.503756  394.96896    -0.846305     -1.334756      0.109367    4.46953
# 254    2.503756  377.73688    -0.843906     -1.334753      0.109364    4.02753
# 255    2.503756  394.96896    -0.843991     -1.334755      0.109361    4.54053
#
# [256 rows x 47 columns]

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={"figure.dpi":300, 'savefig.dpi':300})
try:
    sns.set_theme(style="white")
    
    # Generate a large random dataset
    # Compute the correlation matrix
    corr = df.corr()
    
    # Generate a mask for the upper triangle
    mask = np.triu(np.ones_like(corr, dtype=bool))
    
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(15, 12))
    
    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    
    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5})
    plt.show(df)
except ValueError:
    pass
# Out:
# Executing shutdown due to inactivity...
# 2021-08-26 23:08:29,879 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2021-08-26 23:08:31,937 - INFO     - Executing shutdown...
